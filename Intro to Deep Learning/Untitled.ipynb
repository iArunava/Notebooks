# %% [markdown]
# # Intro to Deep Learning

# %% [markdown]
# ## Perceptron

# %%
import torch
import torch.nn as nn

class Perceptron(nn.Module):
    def __init__(self, threshold=5):
        super().__init__()
        self.weight = nn.Parameter(torch.randn(1))
        self.bias = nn.Parameter(torch.randn(1))
        #self.heaviside_step_function = lambda x : x < threshold
        self.threshold = threshold
        
    def forward(self, x):
        x = self.weight * x
        x += self.bias
        #x = x < self.threshold
        x = x.float()
        #x = self.heaviside_step_function(x).float()
        return x
    
net = Perceptron()

# %%
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset

x = torch.randint(-10, 10, size=(1000,))
y = x > 5
tr = TensorDataset(x, y)
tloader = DataLoader(tr, batch_size=4, shuffle=True)

x = torch.randint(0, 10, size=(1000,))
y = x > 5
va = TensorDataset(x, y)
vloader = DataLoader(va, batch_size=4, shuffle=True)

# %%
# We will use a simple Mean Squared Error
def mse(preds, target):
  se = ((preds - target.float()) ** 2).sum()
  mse = se / len(preds)
  print (mse)
  return nn.Parameter(mse)

# We will use a simple Mean Squared Error
def mse(preds, target):
    preds, target = preds.float(), target.float()
    loss = torch.numel(preds) - (preds == target).sum()
    return nn.Parameter(loss.float())

# %%
import torch.optim as optim

def train(net, crit, trl, val, epochs=5, lr=0.01, clf=True, bclf=-1, dev='cuda'):
  # Initialize the Optimizer
  opt = optim.Adam(net.parameters(), lr=lr)
  dev = 'cuda' if torch.cuda.is_available() and dev == 'cuda' else 'cpu'
  net.to(dev)
  for i in range(epochs):
    for data, labl in trl:
      data, labl = data.to(dev), labl.to(dev)
      if clf and bclf != -1: labl = (labl == bclf).unsqueeze(1).float()
      out = net(data.float())
      #print (out, labl)
      loss = crit(out, labl.float())
      #print (loss)
      opt.zero_grad()
      loss.backward()
      opt.step()
    
    with torch.no_grad():
      acc = 0; vloss = 0;
      for data, labl in val:
        data, labl = data.to(dev), labl.to(dev)
        if clf and bclf != -1: labl = (labl == bclf).unsqueeze(1).float()
        out = net(data.float())
        vloss += crit(out, labl).detach().cpu().numpy().item()
        if clf: plabl = torch.argmax(out, dim=0)
        if clf and bclf != -1: plabl = plabl.reshape(-1, 1).float()
        if clf: acc += (labl.float() == plabl.float()).detach().cpu().sum().numpy()
      
      vloss /= (len(val) * val.batch_size)
      if clf:
        acc /= float(len(val))
        print ('Epoch {}/{} - Validation Loss {:.2f} - Accuracy - {:.2f}'.format(i+1, epochs,
          vloss, acc))
      else:
        print ('Epoch {}/{} - Validation Loss {:.2f}'.format(i+1, epochs, vloss))

# %%
train(net, mse, tloader, vloader, epochs=100, lr=0.01, dev='cpu', bclf=1)
# Out:
# Epoch 1/100 - Validation Loss 1.00 - Accuracy - 0.86
# Epoch 2/100 - Validation Loss 1.00 - Accuracy - 0.81
# Epoch 3/100 - Validation Loss 1.00 - Accuracy - 0.96
# Epoch 4/100 - Validation Loss 1.00 - Accuracy - 0.90
# Epoch 5/100 - Validation Loss 1.00 - Accuracy - 0.83
# Epoch 6/100 - Validation Loss 1.00 - Accuracy - 0.94
# Epoch 7/100 - Validation Loss 1.00 - Accuracy - 0.79
# Epoch 8/100 - Validation Loss 1.00 - Accuracy - 0.84
# Epoch 9/100 - Validation Loss 1.00 - Accuracy - 0.93
# Epoch 10/100 - Validation Loss 1.00 - Accuracy - 0.64
# Epoch 11/100 - Validation Loss 1.00 - Accuracy - 0.99
# Epoch 12/100 - Validation Loss 1.00 - Accuracy - 0.94
# Epoch 13/100 - Validation Loss 1.00 - Accuracy - 0.84
# Epoch 14/100 - Validation Loss 1.00 - Accuracy - 0.75
# Epoch 15/100 - Validation Loss 1.00 - Accuracy - 0.94
# Epoch 16/100 - Validation Loss 1.00 - Accuracy - 0.81
# Epoch 17/100 - Validation Loss 1.00 - Accuracy - 0.92
# Epoch 18/100 - Validation Loss 1.00 - Accuracy - 0.88
# Epoch 19/100 - Validation Loss 1.00 - Accuracy - 0.77
# Epoch 20/100 - Validation Loss 1.00 - Accuracy - 0.76
# Epoch 21/100 - Validation Loss 1.00 - Accuracy - 0.68
# Epoch 22/100 - Validation Loss 1.00 - Accuracy - 0.93
# Epoch 23/100 - Validation Loss 1.00 - Accuracy - 0.80
# Epoch 24/100 - Validation Loss 1.00 - Accuracy - 0.97
# Epoch 25/100 - Validation Loss 1.00 - Accuracy - 0.90
# Epoch 26/100 - Validation Loss 1.00 - Accuracy - 0.86
# Epoch 27/100 - Validation Loss 1.00 - Accuracy - 0.92
# Epoch 28/100 - Validation Loss 1.00 - Accuracy - 0.93
# Epoch 29/100 - Validation Loss 1.00 - Accuracy - 0.75
# Epoch 30/100 - Validation Loss 1.00 - Accuracy - 0.86
# Epoch 31/100 - Validation Loss 1.00 - Accuracy - 0.85
# Epoch 32/100 - Validation Loss 1.00 - Accuracy - 0.96
# Epoch 33/100 - Validation Loss 1.00 - Accuracy - 0.84
# Epoch 34/100 - Validation Loss 1.00 - Accuracy - 0.96
# Epoch 35/100 - Validation Loss 1.00 - Accuracy - 0.91
# Epoch 36/100 - Validation Loss 1.00 - Accuracy - 0.84
# Epoch 37/100 - Validation Loss 1.00 - Accuracy - 0.80
# Epoch 38/100 - Validation Loss 1.00 - Accuracy - 0.68
# Epoch 39/100 - Validation Loss 1.00 - Accuracy - 0.83
# Epoch 40/100 - Validation Loss 1.00 - Accuracy - 0.92
# Epoch 41/100 - Validation Loss 1.00 - Accuracy - 0.78
# Epoch 42/100 - Validation Loss 1.00 - Accuracy - 0.90
# Epoch 43/100 - Validation Loss 1.00 - Accuracy - 0.84
# Epoch 44/100 - Validation Loss 1.00 - Accuracy - 0.85
# Epoch 45/100 - Validation Loss 1.00 - Accuracy - 0.90
# Epoch 46/100 - Validation Loss 1.00 - Accuracy - 0.81
# Epoch 47/100 - Validation Loss 1.00 - Accuracy - 0.77
# Epoch 48/100 - Validation Loss 1.00 - Accuracy - 0.84
# Epoch 49/100 - Validation Loss 1.00 - Accuracy - 0.81
# Epoch 50/100 - Validation Loss 1.00 - Accuracy - 0.68
# Epoch 51/100 - Validation Loss 1.00 - Accuracy - 0.88
# Epoch 52/100 - Validation Loss 1.00 - Accuracy - 0.95
# Epoch 53/100 - Validation Loss 1.00 - Accuracy - 0.92
# Epoch 54/100 - Validation Loss 1.00 - Accuracy - 0.84
# Epoch 55/100 - Validation Loss 1.00 - Accuracy - 0.90
# Epoch 56/100 - Validation Loss 1.00 - Accuracy - 0.77
# Epoch 57/100 - Validation Loss 1.00 - Accuracy - 0.85
# Epoch 58/100 - Validation Loss 1.00 - Accuracy - 0.83
# Epoch 59/100 - Validation Loss 1.00 - Accuracy - 0.89
# Epoch 60/100 - Validation Loss 1.00 - Accuracy - 0.79
# Epoch 61/100 - Validation Loss 1.00 - Accuracy - 0.92
# Epoch 62/100 - Validation Loss 1.00 - Accuracy - 0.75
# Epoch 63/100 - Validation Loss 1.00 - Accuracy - 0.74
# Epoch 64/100 - Validation Loss 1.00 - Accuracy - 0.77
# Epoch 65/100 - Validation Loss 1.00 - Accuracy - 0.81
# Epoch 66/100 - Validation Loss 1.00 - Accuracy - 0.85
# Epoch 67/100 - Validation Loss 1.00 - Accuracy - 0.93
# Epoch 68/100 - Validation Loss 1.00 - Accuracy - 0.77
# Epoch 69/100 - Validation Loss 1.00 - Accuracy - 0.80
# Epoch 70/100 - Validation Loss 1.00 - Accuracy - 0.62
# Epoch 71/100 - Validation Loss 1.00 - Accuracy - 0.98
# Epoch 72/100 - Validation Loss 1.00 - Accuracy - 0.90
# Epoch 73/100 - Validation Loss 1.00 - Accuracy - 0.82
# Epoch 74/100 - Validation Loss 1.00 - Accuracy - 0.77
# Epoch 75/100 - Validation Loss 1.00 - Accuracy - 0.71
# Epoch 76/100 - Validation Loss 1.00 - Accuracy - 0.85
# Epoch 77/100 - Validation Loss 1.00 - Accuracy - 0.93
# Epoch 78/100 - Validation Loss 1.00 - Accuracy - 0.82
# Epoch 79/100 - Validation Loss 1.00 - Accuracy - 0.77
# Epoch 80/100 - Validation Loss 1.00 - Accuracy - 0.90
# Epoch 81/100 - Validation Loss 1.00 - Accuracy - 0.77
# Epoch 82/100 - Validation Loss 1.00 - Accuracy - 0.84
# Epoch 83/100 - Validation Loss 1.00 - Accuracy - 0.88
# Epoch 84/100 - Validation Loss 1.00 - Accuracy - 0.82
# Epoch 85/100 - Validation Loss 1.00 - Accuracy - 0.83
# Epoch 86/100 - Validation Loss 1.00 - Accuracy - 0.80
# Epoch 87/100 - Validation Loss 1.00 - Accuracy - 0.77
# Epoch 88/100 - Validation Loss 1.00 - Accuracy - 0.74
# Epoch 89/100 - Validation Loss 1.00 - Accuracy - 0.81
# Epoch 90/100 - Validation Loss 1.00 - Accuracy - 0.82
# Epoch 91/100 - Validation Loss 1.00 - Accuracy - 0.88
# Epoch 92/100 - Validation Loss 1.00 - Accuracy - 0.96
# Epoch 93/100 - Validation Loss 1.00 - Accuracy - 0.85
# Epoch 94/100 - Validation Loss 1.00 - Accuracy - 0.86
# Epoch 95/100 - Validation Loss 1.00 - Accuracy - 0.74
# Epoch 96/100 - Validation Loss 1.00 - Accuracy - 0.91
# Epoch 97/100 - Validation Loss 1.00 - Accuracy - 0.79
# Epoch 98/100 - Validation Loss 1.00 - Accuracy - 0.86
# Epoch 99/100 - Validation Loss 1.00 - Accuracy - 0.85
# Epoch 100/100 - Validation Loss 1.00 - Accuracy - 0.87
